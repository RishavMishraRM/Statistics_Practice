# %%
data = [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns
sns.histplot(data_copy, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy.sort()

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)

# %%
data_copy.append(210)

# %%
data_copy.append(290)

# %%
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
sns.histplot(data_copy, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# this is a raw data
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
# this is right skewed data
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
# this is left skewed data
data_copy2 = data.copy()

# %%
data_copy2
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy2.insert(0, -10)

# %%
data_copy2.insert(0, -75)

# %%
data_copy2
# Out:
# [-75, -10, 23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
sns.histplot(data_copy2, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
data2 = pd.read_csv("iris.csv")

# %%
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data2["sepal_length"], kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data2["sepal_width"], kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data2["petal_length"], kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(data2["petal_width"], kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
import numpy as np
normal_distributed_data = np.random.normal(0.5, 0.2, 1000)

# %%
normal_distributed_data
# Out:
# array([ 0.46697252,  0.92346227,  0.39952345,  0.18847358,  0.41999444,
#         0.84866613,  0.49833968,  0.72237519,  0.12945423,  0.84739088,
#         0.28418073,  0.61893677,  0.40491925,  0.52953039,  0.63859962,
#         1.06443099,  0.75295176,  0.49338927,  0.55212895,  0.26195798,
#         0.43404791,  0.37964769,  0.42637376,  0.64771564,  0.29027229,
#         0.43656185,  0.56676987,  0.29444444,  0.2254142 ,  0.5160276 ,
#         0.23252069,  0.66026703,  0.80189478,  0.65164511,  0.59571143,
#         0.23888989,  0.49618614,  0.44492261,  0.88271462,  0.68497006,
#         0.56827615,  0.55208296,  0.34652296,  0.57206926,  0.34449915,
#         0.77472364,  0.36597589,  0.42594197,  0.47686838,  0.32939243,
#         0.50904125,  0.69687297,  0.56727095,  0.33149918,  0.59845177,
#         0.55137719,  0.18364777,  0.07487287,  0.61726699,  0.32894451,
#         0.77098763,  0.84337591,  0.88605014,  0.61296906,  0.46903987,
#         0.4975526 ,  0.40219598,  0.68744199,  0.34671293,  0.48586826,
#        -0.18250914, -0.04215896,  0.1462522 ,  0.73171537,  0.25447919,
#         0.50509531,  0.66005049, -0.20704566,  0.46686849,  0.34352115,
#         0.54301655,  0.67442957,  0.90600072,  0.3245098 ,  0.77615221,
#         0.75088304,  0.4894356 ,  0.48391598,  0.224578  ,  0.52828482,
#         0.43824057,  0.8676823 ,  0.50598058,  0.49428976,  0.48134566,
#         0.23281151,  0.67312336,  0.55176525,  0.38126098,  0.42781887,
#         0.44491271,  0.83150877,  0.56367359,  0.47988539,  0.34363372,
#         0.31472555,  0.29858088,  0.60682569,  0.3337942 ,  0.5270185 ,
#         0.7934784 ,  0.26803155,  0.42861724,  0.99131722,  0.49075939,
#         0.68562666,  0.19310417,  0.33408388,  0.66170089,  0.33306598,
#         0.69793521,  0.54794741,  0.61087098,  0.50568195,  0.58752995,
#         0.77763027,  0.52567407,  0.81024509,  0.48619741,  0.45810387,
#         0.60215604,  0.52154592,  0.52536783,  0.66746748,  0.22522158,
#         0.75337397,  0.74555817,  0.14287898,  0.28991973,  0.30617115,
#         0.63467297,  0.60222194,  0.68178286,  0.24684348,  0.51122892,
#         0.36136102,  0.3063806 ,  0.72247573,  0.47464568,  0.38094864,
#         0.54266141,  0.55383614,  0.57020018,  0.24450972,  0.79329362,
#         0.47809301,  0.36197391,  0.35990108,  0.79507522,  0.47346529,
np.random.lognormal(mu, sigma, 1000)

# %%
sns.histplot(lognormal_distributed_data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(lognormal_distributed_data), kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

def plot_data(sample):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(sample,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(sample,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(lognormal_distributed_data)

# %%
plot_data(np.log(lognormal_distributed_data))

# %%
from numpy import random
sns.distplot(random.uniform(size=500), hist=False)
# Out:
# C:\Users\Rishav\AppData\Local\Temp\ipykernel_20960\861918089.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=500), hist=False)
# <Axes: ylabel='Density'>

# %%
sns.histplot(np.random.randint(1, 8, size=800))
# Out:
# <Axes: ylabel='Count'>

# %%
p = 0.3
sample_size = 1000

bernouli_data = np.random.choice([0, 1], size = sample_size, p=[1-p, p])

sns.histplot(bernouli_data, bins=2, kde=False, color="blue")
# Out:
# <Axes: ylabel='Count'>

# %%
no_of_trials = 10
probability = 0.6

data3 = np.random.binomial(no_of_trials, probability, 10000)

# %%
sns.displot(data3)

# %%
poisson_data = np.random.poisson(lam=5, size=1000)

# plotting a histogram
ax = sns.distplot(poisson_data,
                  kde=False,
                  color='blue')
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# C:\Users\Rishav\AppData\Local\Temp\ipykernel_20960\1762229923.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(poisson_data,
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ### Central Limit Theroem

# %%
population = np.random.randint(10, 20, 50)
population
# Out:
# array([10, 12, 15, 11, 16, 11, 15, 12, 17, 17, 12, 17, 19, 15, 19, 13, 12,
#        19, 17, 13, 18, 14, 19, 14, 10, 14, 16, 19, 18, 11, 16, 15, 17, 15,
#        15, 19, 18, 11, 15, 12, 15, 11, 18, 16, 18, 15, 13, 15, 13, 16])

# %%
np.mean(population)
# Out:
# 14.96

# %%
np.median(population)
# Out:
# 15.0

# %%
from statistics import mode
mode(population)
# Out:
# 15

# %%
# random sample from the population
sample = np.random.choice(population, 20)

# %%
print(f"mean of the sample {np.mean(sample)}")
print(f"median of the sample {np.median(sample)}")
print(f"mode of the sample {mode(sample)}")
# Out:
# mean of the sample 15.0
# median of the sample 15.0
# mode of the sample 12

# %%
sample1 = np.random.choice(population, 20)
sample2 = np.random.choice(population, 20)
sample3 = np.random.choice(population, 20)
sample4 = np.random.choice(population, 20)

# %%
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
print(60*"=")
# Out:
# [15 15 18 12 17 19 19 19 11 10 18 15 19 12 13 16 16 12 15 13]
# ============================================================
# [10 15 19 11 15 18 18 15 19 14 15 14 18 15 19 15 18 15 13 16]
# ============================================================
# [15 12 14 16 19 15 13 15 12 14 10 16 18 17 15 16 16 15 15 13]
# ============================================================
# [10 15 18 16 12 10 16 17 11 13 18 17 15 19 15 12 15 14 19 19]
# ============================================================

# %%
mean_of_the_sample = []
all_sample = [sample1, sample2, sample3, sample4]
for sample in all_sample:
    print(np.mean(sample))
    mean_of_the_sample.append(np.mean(sample))
# Out:
# 15.2
# 15.6
# 14.8
# 15.05

# %%
mean_of_the_sample
# Out:
# [15.2, 15.6, 14.8, 15.05]

# %%
#binomial distribution
population = np.random.binomial(10, 0.5, 10000)

# %%
population
# Out:
# array([4, 6, 6, ..., 4, 4, 4])

# %%
len(population)
# Out:
# 10000

# %%
sns.displot(population)
